# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'studentsperformance'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

stu_df = pd.read_sql_query('select * from studentsperformance',con=engine)
stu_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
stu_1 = stu_df.copy()
stu_2 = stu_df.copy()
stu_3 = stu_df.copy()
stu_gender = pd.DataFrame(stu_1.groupby('gender').mean())
stu_race = pd.DataFrame(stu_2.groupby('race/ethnicity').mean())
stu_edu = pd.DataFrame(stu_3.groupby('parental level of education').mean())
plt.figure(figsize = (18,5))
plt.subplot(1,3,1)
sns.barplot(stu_gender.index, stu_gender['math score'])
plt.subplot(1,3,2)
sns.barplot(stu_gender.index, stu_gender['reading score'])
plt.subplot(1,3,3)
sns.barplot(stu_gender.index, stu_gender['writing score'])
plt.show()
stu_gender
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
plt.figure(figsize = (18,5))
plt.subplot(1,3,1)
sns.barplot(stu_race.index, stu_race['math score'])
plt.subplot(1,3,2)
sns.barplot(stu_race.index, stu_race['reading score'])
plt.subplot(1,3,3)
sns.barplot(stu_race.index, stu_race['writing score'])
plt.show()
stu_race
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %%
plt.figure(figsize = (18,18))
plt.subplot(3,1,1)
sns.barplot(stu_edu.index, stu_edu['math score'])
plt.subplot(3,1,2)
sns.barplot(stu_edu.index, stu_edu['reading score'])
plt.subplot(3,1,3)
sns.barplot(stu_edu.index, stu_edu['writing score'])
plt.tight_layout()
plt.show()
stu_edu
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
stu_4 = stu_df.copy()
stu_lunch = pd.DataFrame(stu_4.groupby('lunch').mean())
plt.figure(figsize = (18,5))
plt.subplot(1,3,1)
sns.barplot(stu_lunch.index, stu_lunch['math score'])
plt.subplot(1,3,2)
sns.barplot(stu_lunch.index, stu_lunch['reading score'])
plt.subplot(1,3,3)
sns.barplot(stu_lunch.index, stu_lunch['writing score'])
plt.show()
stu_lunch
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %%
stu_5 = stu_df.copy()
stu_prep = pd.DataFrame(stu_5.groupby('test preparation course').mean())
plt.figure(figsize = (18,5))
plt.subplot(1,3,1)
sns.barplot(stu_prep.index, stu_prep['math score'])
plt.subplot(1,3,2)
sns.barplot(stu_prep.index, stu_prep['reading score'])
plt.subplot(1,3,3)
sns.barplot(stu_prep.index, stu_prep['writing score'])
plt.show()
stu_prep
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %%
stu_cor = stu_df[['math score', 'reading score', 'writing score']].corr()
sns.heatmap(stu_cor, square = True, annot = True)
stu_cor
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000
