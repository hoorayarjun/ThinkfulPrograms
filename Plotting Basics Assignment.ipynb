# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
playstore = pd.read_csv("googleplaystore.csv")
cleaned_ratings = []
installs_values = []
for x in range (len(playstore['Rating'])):
    if(playstore['Rating'][x] != 'NaN' and playstore['Installs'][x] != 'Free'):
        cleaned_ratings.append(playstore['Rating'][x])
        installs_values.append(playstore['Installs'][x].replace(',','').replace('+',''))
plt.subplot(1,2,1)
plt.hist(cleaned_ratings, bins = 25, color = 'red', range = (0,5))
plt.title('Ratings Histogram')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.subplot(1,2,2)
plt.scatter(x = sorted_ratings, y = installs_values, color = 'blue')
plt.title('Ratings vs. Installs')
plt.xlabel("Rating")
plt.ylabel("Install Count")
business_ratings = []
for x in range(len(playstore['Rating'])):
        if(playstore['Category'][x] == 'BUSINESS'):
            business_ratings.append(playstore['Rating'][x])
plt.tight_layout()
plt.show()
plt.subplot(1,2,1)
plt.hist(business_ratings, bins = 10, color = 'green', range = (1,5))
plt.title('Business Ratings Histogram')
plt.xlabel("Rating")
plt.ylabel("Count")
plt.subplot(1,2,2)
game_ratings = []
for x in range(len(playstore['Rating'])):
    if(playstore['Category'][x] == 'GAME' and playstore['Rating'][x] != "NaN"):
        game_ratings.append(playstore['Rating'][x])
plt.hist(game_ratings, bins = 10, color = 'orange', range = (1,5))
plt.title('Games Ratings Histogram')
plt.xlabel("Rating")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# 1st Visual:
#
#     This graph shows that the distribution of ratings of applications on the google play store is not, in fact, normally distributed, but rather skewed toward the left. This means that the mean rating for a group of applications which is representative of the whole marketplace is likely not as useful a measure as the median because there tend to be a concentration of applications with ratings around four and a few that go far below that.
#
# 2nd Visual:
#
#     This graph was meant to determine whether there is any kind of relationship between the rating which an application recieves and the number of people who opt to download it. While the graph does not show what the ratings of the applications where when people download them were, it does seem to show that there is very little or no relationship between the popularity of an application and the rating it recieves. This means that if one were to develop an application, it would be less helpful to use the rating of the application as a primary metric for success.
#
# 3rd Visual:
#
#     This graph shows the distribution of ratings for applications in the Business category. It seems to show roughly the same distribution as for them market in general, with a left skew and a concentration of applications with ratings around 4.
#
# 4th Visual:
#
#     This graph shows the dsitribution of ratings for applications in the Games category. It also seems to show roughly the same distribution as the whole marketplace, however, there seem to be fewer low rated applications, showing that there is an even stronger concentration of applications with ratings in the upper 4's.
