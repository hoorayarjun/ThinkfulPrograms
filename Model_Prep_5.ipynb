# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'useducation'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

edu_df = pd.read_sql_query('select * from useducation',con=engine)
edu_df
# Out:
#                     PRIMARY_KEY                 STATE  YEAR  ENROLL  \
# 0                  1992_ALABAMA               ALABAMA  1992     NaN
# 1                   1992_ALASKA                ALASKA  1992     NaN
# 2                  1992_ARIZONA               ARIZONA  1992     NaN
# 3                 1992_ARKANSAS              ARKANSAS  1992     NaN
# 4               1992_CALIFORNIA            CALIFORNIA  1992     NaN
# 5                 1992_COLORADO              COLORADO  1992     NaN
# 6              1992_CONNECTICUT           CONNECTICUT  1992     NaN
# 7                 1992_DELAWARE              DELAWARE  1992     NaN
# 8     1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992     NaN
# 9                  1992_FLORIDA               FLORIDA  1992     NaN
# 10                 1992_GEORGIA               GEORGIA  1992     NaN
# 11                  1992_HAWAII                HAWAII  1992     NaN
# 12                   1992_IDAHO                 IDAHO  1992     NaN
# ...

# %%
edu_df.describe()
# Out:
#               YEAR        ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# count  1492.000000  1.229000e+03   1.280000e+03     1.280000e+03
# mean   2004.433646  9.159308e+05   9.092082e+06     7.663723e+05
# std       7.393983  1.065280e+06   1.174519e+07     1.145242e+06
# min    1992.000000  4.386600e+04   4.656500e+05     3.102000e+04
# 25%    1998.000000  2.583140e+05   2.186305e+06     1.893540e+05
# 50%    2004.000000  6.483130e+05   5.079546e+06     4.033765e+05
# 75%    2011.000000  1.014528e+06   1.085985e+07     8.289660e+05
# max    2017.000000  6.307022e+06   8.921726e+07     9.990221e+06
#
#        STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# count   1.280000e+03   1.280000e+03       1.280000e+03
# mean    4.216553e+06   4.109157e+06       9.196681e+06
# std     5.543072e+06   5.482971e+06       1.197813e+07
# min     0.000000e+00   2.209300e+04       4.816650e+05
# 25%     1.153097e+06   7.158345e+05       2.165404e+06
# ...

# %%
plt.subplot(1,2,1)
plt.scatter(x = edu_df['YEAR'].unique(), y = edu_df.loc[edu_df['STATE'] == 'CALIFORNIA']['TOTAL_REVENUE'])
plt.subplot(1,2,2)
plt.scatter(x = edu_df['YEAR'].unique(), y = edu_df.loc[edu_df['STATE'] == 'CALIFORNIA']['TOTAL_EXPENDITURE'])
plt.tight_layout()
plt.show()

# %%
plt.subplot(1,2,1)
plt.scatter(x = edu_df['YEAR'].unique(), y = edu_df.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_MATH_8_SCORE'])
plt.subplot(1,2,2)
plt.scatter(x = edu_df['YEAR'].unique(), y = edu_df.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_READING_8_SCORE'])
plt.tight_layout()
plt.show()

# %%
plt.subplot(1,2,1)
plt.hist(edu_df.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_MATH_4_SCORE'])
plt.subplot(1,2,2)
plt.hist(edu_df.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_READING_4_SCORE'])
plt.show()

# %%
edu_states = []
for state in edu_df['STATE'].unique():
    edu_states.append(edu_df.loc[edu_df['STATE'] == state])
for x in range(len(edu_states)):
    df = edu_states[x]
    df['AVG_MATH_4_SCORE'].fillna(df['AVG_MATH_4_SCORE'].mean(), inplace = True)
    df['AVG_READING_4_SCORE'].fillna(df['AVG_READING_4_SCORE'].mean(), inplace = True)
    edu_states[x] = df
edu_remerged = edu_states[0]
for x in range(1, len(edu_states)):
    edu_remerged = pd.concat([edu_remerged, edu_states[x]])
edu_remerged.sort_index()
plt.subplot(1,2,1)
plt.scatter(x = edu_remerged['YEAR'].unique(), y = edu_remerged.loc[edu_remerged['STATE'] == 'CALIFORNIA']['AVG_MATH_4_SCORE'])
plt.subplot(1,2,2)
plt.scatter(x = edu_remerged['YEAR'].unique(), y = edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_READING_4_SCORE'])
plt.tight_layout()
plt.show()
plt.subplot(1,2,1)
plt.hist(edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_MATH_4_SCORE'])
plt.subplot(1,2,2)
plt.hist(edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_READING_4_SCORE'])
plt.show()

# %%
edu_interpolated = edu_df.copy()
edu_interpolated.interpolate(method = 'linear', inplace = True, limit_direction = 'both')

# %%
edu_states = []
for state in edu_df['STATE'].unique():
    edu_states.append(edu_df.loc[edu_df['STATE'] == state])
for x in range(len(edu_states)):
    df = edu_states[x]
    df.interpolate(method = 'linear', inplace = True, limit_direction = 'both')
    edu_states[x] = df
edu_remerged = edu_states[0]
for x in range(1, len(edu_states)):
    edu_remerged = pd.concat([edu_remerged, edu_states[x]])
plt.subplot(1,2,1)
plt.scatter(x = edu_remerged['YEAR'].unique(), y = edu_remerged.loc[edu_remerged['STATE'] == 'CALIFORNIA']['AVG_MATH_4_SCORE'])
plt.subplot(1,2,2)
plt.scatter(x = edu_remerged['YEAR'].unique(), y = edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_READING_4_SCORE'])
plt.tight_layout()
plt.show()
plt.subplot(1,2,1)
plt.hist(edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_MATH_4_SCORE'])
plt.subplot(1,2,2)
plt.hist(edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_READING_4_SCORE'])
plt.show()
edu_remerged.sort_index()
# Out:
#                     PRIMARY_KEY                 STATE  YEAR     ENROLL  \
# 0                  1992_ALABAMA               ALABAMA  1992   727716.0
# 1                   1992_ALASKA                ALASKA  1992   121156.0
# 2                  1992_ARIZONA               ARIZONA  1992   676297.0
# 3                 1992_ARKANSAS              ARKANSAS  1992   311432.0
# 4               1992_CALIFORNIA            CALIFORNIA  1992  5129788.0
# 5                 1992_COLORADO              COLORADO  1992   539538.0
# 6              1992_CONNECTICUT           CONNECTICUT  1992   471918.0
# 7                 1992_DELAWARE              DELAWARE  1992   104355.0
# 8     1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992    80937.0
# 9                  1992_FLORIDA               FLORIDA  1992  1980569.0
# 10                 1992_GEORGIA               GEORGIA  1992   893557.0
# 11                  1992_HAWAII                HAWAII  1992   177448.0
# ...

# %%
edu_states = []
for state in edu_df['STATE'].unique():
    edu_states.append(edu_df.loc[edu_df['STATE'] == state])
for x in range(len(edu_states)):
    df = edu_states[x]
    df['AVG_MATH_4_SCORE'].fillna(df['AVG_MATH_4_SCORE'].median(), inplace = True)
    df['AVG_READING_4_SCORE'].fillna(df['AVG_READING_4_SCORE'].median(), inplace = True)
    edu_states[x] = df
edu_remerged = edu_states[0]
for x in range(1, len(edu_states)):
    edu_remerged = pd.concat([edu_remerged, edu_states[x]])
edu_remerged.sort_index()
plt.subplot(1,2,1)
plt.scatter(x = edu_remerged['YEAR'].unique(), y = edu_remerged.loc[edu_remerged['STATE'] == 'CALIFORNIA']['AVG_MATH_4_SCORE'])
plt.subplot(1,2,2)
plt.scatter(x = edu_remerged['YEAR'].unique(), y = edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_READING_4_SCORE'])
plt.tight_layout()
plt.show()
plt.subplot(1,2,1)
plt.hist(edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_MATH_4_SCORE'])
plt.subplot(1,2,2)
plt.hist(edu_remerged.loc[edu_df['STATE'] == 'CALIFORNIA']['AVG_READING_4_SCORE'])
plt.show()
