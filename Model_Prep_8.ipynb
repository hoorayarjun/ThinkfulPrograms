# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
warnings.filterwarnings('ignore')

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'useducation'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

edu_df = pd.read_sql_query('select * from useducation',con=engine)
edu_df
# Out:
#                     PRIMARY_KEY                 STATE  YEAR  ENROLL  \
# 0                  1992_ALABAMA               ALABAMA  1992     NaN
# 1                   1992_ALASKA                ALASKA  1992     NaN
# 2                  1992_ARIZONA               ARIZONA  1992     NaN
# 3                 1992_ARKANSAS              ARKANSAS  1992     NaN
# 4               1992_CALIFORNIA            CALIFORNIA  1992     NaN
# 5                 1992_COLORADO              COLORADO  1992     NaN
# 6              1992_CONNECTICUT           CONNECTICUT  1992     NaN
# 7                 1992_DELAWARE              DELAWARE  1992     NaN
# 8     1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992     NaN
# 9                  1992_FLORIDA               FLORIDA  1992     NaN
# 10                 1992_GEORGIA               GEORGIA  1992     NaN
# 11                  1992_HAWAII                HAWAII  1992     NaN
# 12                   1992_IDAHO                 IDAHO  1992     NaN
# ...

# %%
edu_df.sort_values(by = ['STATE', 'YEAR'], inplace = True)
edu_df
# Out:
#          PRIMARY_KEY      STATE  YEAR    ENROLL  TOTAL_REVENUE  \
# 0       1992_ALABAMA    ALABAMA  1992       NaN      2678885.0
# 52      1993_ALABAMA    ALABAMA  1993  727716.0      2827391.0
# 104     1994_ALABAMA    ALABAMA  1994  730004.0      2970223.0
# 157     1995_ALABAMA    ALABAMA  1995  727480.0      3367437.0
# 209     1996_ALABAMA    ALABAMA  1996  735912.0      3365113.0
# 260     1997_ALABAMA    ALABAMA  1997  737386.0      3981788.0
# 312     1998_ALABAMA    ALABAMA  1998  739321.0      4140537.0
# 363     1999_ALABAMA    ALABAMA  1999  737639.0      4471546.0
# 416     2000_ALABAMA    ALABAMA  2000  730184.0      4885917.0
# 468     2001_ALABAMA    ALABAMA  2001  728532.0      4832946.0
# 520     2002_ALABAMA    ALABAMA  2002  726367.0      5128559.0
# 572     2003_ALABAMA    ALABAMA  2003  727900.0      5196054.0
# 624     2004_ALABAMA    ALABAMA  2004  730418.0      5356113.0
# 676     2005_ALABAMA    ALABAMA  2005  729342.0      5889966.0
# ...

# %%
for state in edu_df['STATE'].unique(): 
    edu_df.loc[edu_df['STATE'] == state] = edu_1.loc[edu_1['STATE'] == state].interpolate(method = 'linear', limit_direction = 'both')
edu_df.dropna(inplace = True)
edu_df['WEIGHTED_SCORES'] = (edu_df['GRADES_4_G']*edu_df['AVG_MATH_4_SCORE'] + edu_df['GRADES_8_G']*edu_df['AVG_MATH_8_SCORE'] + edu_df['GRADES_4_G']*edu_df['AVG_READING_4_SCORE'] + edu_df['GRADES_8_G']*edu_df['AVG_READING_8_SCORE'])/(2*edu_df['GRADES_4_G'] + 2*edu_df['GRADES_8_G'])
edu_df
# Out:
#          PRIMARY_KEY      STATE  YEAR    ENROLL  TOTAL_REVENUE  \
# 0       1992_ALABAMA    ALABAMA  1992  727716.0      2678885.0
# 52      1993_ALABAMA    ALABAMA  1993  727716.0      2827391.0
# 104     1994_ALABAMA    ALABAMA  1994  730004.0      2970223.0
# 157     1995_ALABAMA    ALABAMA  1995  727480.0      3367437.0
# 209     1996_ALABAMA    ALABAMA  1996  735912.0      3365113.0
# 260     1997_ALABAMA    ALABAMA  1997  737386.0      3981788.0
# 312     1998_ALABAMA    ALABAMA  1998  739321.0      4140537.0
# 363     1999_ALABAMA    ALABAMA  1999  737639.0      4471546.0
# 416     2000_ALABAMA    ALABAMA  2000  730184.0      4885917.0
# 468     2001_ALABAMA    ALABAMA  2001  728532.0      4832946.0
# 520     2002_ALABAMA    ALABAMA  2002  726367.0      5128559.0
# 572     2003_ALABAMA    ALABAMA  2003  727900.0      5196054.0
# 624     2004_ALABAMA    ALABAMA  2004  730418.0      5356113.0
# 676     2005_ALABAMA    ALABAMA  2005  729342.0      5889966.0
# ...

# %%
edu_corr = edu_df[['WEIGHTED_SCORES', "INSTRUCTION_EXPENDITURE", "SUPPORT_SERVICES_EXPENDITURE", "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE"]].corr()
edu_corr
# Out:
#                               WEIGHTED_SCORES  INSTRUCTION_EXPENDITURE  \
# WEIGHTED_SCORES                      1.000000                 0.133105
# INSTRUCTION_EXPENDITURE              0.133105                 1.000000
# SUPPORT_SERVICES_EXPENDITURE         0.134274                 0.976228
# OTHER_EXPENDITURE                    0.062597                 0.908494
# CAPITAL_OUTLAY_EXPENDITURE           0.060536                 0.893354
#
#                               SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE  \
# WEIGHTED_SCORES                                   0.134274           0.062597
# INSTRUCTION_EXPENDITURE                           0.976228           0.908494
# SUPPORT_SERVICES_EXPENDITURE                      1.000000           0.953215
# OTHER_EXPENDITURE                                 0.953215           1.000000
# CAPITAL_OUTLAY_EXPENDITURE                        0.915092           0.920356
#
#                               CAPITAL_OUTLAY_EXPENDITURE
# ...

# %%
sklearn_pca = PCA(n_components = 4)
X = StandardScaler().fit_transform(edu_df[['WEIGHTED_SCORES', "INSTRUCTION_EXPENDITURE", "SUPPORT_SERVICES_EXPENDITURE", "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE"]])
Y_sklearn = sklearn_pca.fit_transform(X)
print(
    'The percentage of total variance in the dataset explained by each',
    'component from Sklearn PCA.\n',
    sklearn_pca.explained_variance_ratio_
)
# Out:
# [[-1.15050966  2.00972163 -0.12702979 -0.09801784]
#  [-1.11341194  1.85724718 -0.11241836 -0.0869885 ]
#  [-1.01752706  1.78226081 -0.08132009 -0.17352217]
#  ...
#  [-1.09710063 -0.97481877  0.22330821  0.15682342]
#  [-1.06244339 -1.14603875  0.25654383  0.16866958]
#  [-1.05022797 -1.31991957  0.2694805   0.16463792]]
# The percentage of total variance in the dataset explained by each component from Sklearn PCA.
#  [0.75950725 0.19839077 0.02391675 0.01547248]

# %%
edu_comp = pd.DataFrame(edu_df['WEIGHTED_SCORES'])
Y_sklearn = pd.DataFrame(Y_sklearn)
edu_comp['Component 1'] = Y_sklearn[0]
edu_comp['Component 2'] = Y_sklearn[1]
edu_comp['Component 3'] = Y_sklearn[2]
edu_comp['Component 4'] = Y_sklearn[3]
edu_comp.corr()
# Out:
#                  WEIGHTED_SCORES  Component 1  Component 2  Component 3  \
# WEIGHTED_SCORES         1.000000     0.008880    -0.254855    -0.009944
# Component 1             0.008880     1.000000    -0.005721     0.004165
# Component 2            -0.254855    -0.005721     1.000000     0.000926
# Component 3            -0.009944     0.004165     0.000926     1.000000
# Component 4             0.080175     0.005151     0.000577    -0.006161
#
#                  Component 4
# WEIGHTED_SCORES     0.080175
# Component 1         0.005151
# Component 2         0.000577
# Component 3        -0.006161
# Component 4         1.000000
